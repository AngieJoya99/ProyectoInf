# %%
import pandas as pd
import numpy as np
import h5py
import os
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from torchvision.datasets import ImageFolder, CIFAR10
from torchvision import transforms
from torch import nn, optim
from collections import OrderedDict
from sklearn.model_selection import train_test_split

import pickle
from PIL import Image
import requests
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score
import seaborn as sn
from sklearn import preprocessing

torch.manual_seed(1) # Set manual seed

# %%
#Definir variables globales
ancho = 32
alto = 32
canales = 3
pixeles = ancho*alto*canales
cantidadClases = 10
clases = ['Avión', 'Carro', 'Pájaro', 'Gato', 'Ciervo', 'Perro', 'Rana', 'Caballo', 'Barco', 'Camión']
batchSize = 100
mean, std = [0.4914, 0.4822, 0.4465], [0.247, 0.243, 0.261]
current_dir = os.getcwd()

# %%
#Transformaciones entrenamiento
train_transform = transforms.Compose(
  [transforms.Resize((ancho, alto)), # Resize the image in a 32X32 shape
  transforms.RandomRotation(20), # Randomly rotate some images by 20 degrees
  transforms.RandomHorizontalFlip(0.1), # Randomly horizontal flip the images
  transforms.ColorJitter(
    brightness = 0.1, # Randomly adjust color jitter of the images
    contrast = 0.1, 
    saturation = 0.1), 
  transforms.RandomAdjustSharpness(
    sharpness_factor = 2,
    p = 0.1), # Randomly adjust sharpness
  transforms.ToTensor(),   # Converting image to tensor
  transforms.Normalize(mean, std), # Normalizing with standard mean and standard deviation
  transforms.RandomErasing(p=0.75,scale=(0.02, 0.1),value=1.0, inplace=False)]
)

#Transformaciones prueba
test_transform = transforms.Compose(
  [transforms.Resize((ancho,alto)),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)]
  )

#Datos de Entrenamiento
dataset_path = os.path.join(current_dir, 'dataset','train')
trainset = CIFAR10(root=dataset_path, train=True, download=True, transform=train_transform)
trainloader = DataLoader(trainset, batch_size=batchSize, shuffle=True)

#Datos de Prueba
testset_path = os.path.join(current_dir, 'dataset','test')
testset = CIFAR10(root=testset_path,train=False, download=True, transform=test_transform)
testloader = DataLoader(testset, batch_size=batchSize, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to c:\Users\ASUS\Desktop\dataset\train\cifar-10-python.tar.gz
# 100.0%
# Extracting c:\Users\ASUS\Desktop\dataset\train\cifar-10-python.tar.gz to c:\Users\ASUS\Desktop\dataset\train
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to c:\Users\ASUS\Desktop\dataset\test\cifar-10-python.tar.gz
# 100.0%
# Extracting c:\Users\ASUS\Desktop\dataset\test\cifar-10-python.tar.gz to c:\Users\ASUS\Desktop\dataset\test

# %%
#Funciones Auxiliares para graficar 
  
def plot_confusion_matrix(cm, class_names, title="Matriz de Confusión"):
  fig, ax = plt.subplots(figsize=(12, 12))
  cax = ax.matshow(cm, cmap=plt.cm.Blues)
  plt.colorbar(cax)

  for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f'{val}', ha='center', va='center', color='black')

  ax.set_xticks(np.arange(len(class_names)))
  ax.set_yticks(np.arange(len(class_names)))
  ax.set_xticklabels(class_names)
  ax.set_yticklabels(class_names)
  plt.xlabel('Predicción')
  plt.ylabel('Real')
  plt.title(title)
  plt.show()

# %%
class Network(nn.Module):
  def __init__(self):
    out_1 = 32
    out_2 = 64
    out_3 = 128
    p = 0.5
    
    super(Network, self).__init__()
    self.cnn1 = nn.Conv2d(in_channels = 3, out_channels = out_1, kernel_size = 5, padding = 2)
    self.maxpool1 = nn.MaxPool2d(kernel_size = 2)
    self.conv1_bn = nn.BatchNorm2d(out_1)
    self.drop_conv = nn.Dropout(p=0.2)
    
    self.cnn2 = nn.Conv2d(in_channels = out_1, out_channels = out_2, kernel_size = 5, padding = 2)
    self.maxpool2 = nn.MaxPool2d(kernel_size = 2)
    self.conv2_bn = nn.BatchNorm2d(out_2) 
    
    self.cnn3 = nn.Conv2d(in_channels = out_2, out_channels = out_3, kernel_size = 5, padding = 2)
    self.maxpool3 = nn.MaxPool2d(kernel_size = 2)
    self.conv3_bn = nn.BatchNorm2d(out_3)
    
    # Hidden layer 1
    self.fc1 = nn.Linear(out_3 * 4 * 4, 1000) 
    self.drop = nn.Dropout(p=p)
    self.fc1_bn = nn.BatchNorm1d(1000)
    
    # Hidden layer 2
    self.fc2 = nn.Linear(1000, 1000)
    self.fc2_bn = nn.BatchNorm1d(1000)

    # Hidden layer 3
    self.fc3 = nn.Linear(1000, 1000)
    self.fc3_bn = nn.BatchNorm1d(1000)
    
    # Hidden layer 4
    self.fc4 = nn.Linear(1000, 1000)
    self.fc4_bn = nn.BatchNorm1d(1000)
    
    # Final layer
    self.fc5 = nn.Linear(1000, 10)
    self.fc5_bn = nn.BatchNorm1d(10)
      
  def forward(self, x):
      
    x = self.cnn1(x)
    x = self.conv1_bn(x)
    x = self.maxpool1(x)
    x = self.drop_conv(x)
    
    x = self.cnn2(x)
    x = self.conv2_bn(x)
    x = torch.relu(x)
    x = self.maxpool2(x)
    x = self.drop_conv(x)
    
    x = self.cnn3(x)
    x = self.conv3_bn(x)
    x = torch.relu(x)
    x = self.maxpool3(x)
    x = self.drop_conv(x)
    
    x = x.view(x.size(0), -1)
    x = self.fc1(x)
    x = self.fc1_bn(x)
    
    x = F.relu(self.drop(x))
    x = self.fc2(x)
    x = self.fc2_bn(x)
    
    x = F.relu(self.drop(x))
    x = self.fc3(x)
    x = self.fc3_bn(x)
    
    x = F.relu(self.drop(x))
    x = self.fc4(x)
    x = self.fc4_bn(x)

    x = F.relu(self.drop(x))
    x = self.fc5(x)
    x = self.fc5_bn(x)
    
    return(x)

# %%
#Definir la tasa de entrenamiento y la función para el cálculo de pérdidas
model = Network()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum = 0.2)
image, label = next(iter(trainloader))

#Definir la arquitectura del entrenamiento

epochs = 200
steps = 0
train_losses, test_losses = [], []
precisions, recalls, f1_scores, accus, avg_specificities = [], [], [], [], []

# %%
for e in range(epochs):
  running_loss = 0
  for images,labels in trainloader:
    model.train()
    optimizer.zero_grad()
    log_ps = model(images)
    loss = criterion(log_ps,labels)
    loss.backward()
    optimizer.step()
    running_loss+=loss.item()
        
  else:
    test_loss = 0
    accuracy = 0
    all_labels = []
    all_preds = []
    
    # Turn off gradients for validation
    with torch.no_grad():
      for images, labels in testloader:
        model.eval()
        log_ps = model(images)
        test_loss += criterion(log_ps, labels)

        ps = torch.softmax(log_ps, dim=1)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor))
        
        # Save labels and predictions
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(top_class.cpu().numpy())
  
    # Calcular matriz de confusión
    cm = confusion_matrix(all_labels, all_preds)
    
    num_classes = cm.shape[0]
    specificities = []
    for i in range(num_classes):
      tp = cm[i, i]
      fn = cm[i, :].sum() - tp
      fp = cm[:, i].sum() - tp
      tn = cm.sum() - (tp + fn + fp)
      specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
      
      specificities.append(specificity)

    # Calcular métricas ponderadas
    precision_weighted = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
    recall_weighted = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
    f1_weighted = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
    accuracy = accuracy_score(all_labels, all_preds)
    avg_specificity = np.mean(specificities)
    
    train_losses.append(running_loss / len(trainloader))
    test_losses.append(test_loss / len(testloader))
    precisions.append(precision_weighted)
    recalls.append(recall_weighted)
    f1_scores.append(f1_weighted)
    avg_specificities.append(avg_specificity)
    accus.append(accuracy)

    # Print metricas
    print("\nEpoch: {}/{}.. ".format(e + 1, epochs),
      "Training Loss: {:.3f}.. ".format(train_losses[-1]),
      "Test Loss: {:.3f}.. ".format(test_losses[-1]),
      "Test Accuracy: {:.3f}".format(accuracy),
      "Weighted Precision: {:.3f}".format(precision_weighted),
      "Weighted Recall: {:.3f}".format(recall_weighted),
      "Weighted F1 Score: {:.3f}".format(f1_weighted),
      "Average Specificity: {:.3f}".format(avg_specificity))

    
    # Graficar matriz
    if e == epochs - 1:
      print("\nMatriz de Confusión")
      plot_confusion_matrix(cm, clases, title="Matriz de Confusión")
# Out:
# Epoch: 1/200..  Training Loss: 1.712..  Test Loss: 1.346..  Test Accuracy: 0.516 Weighted Precision: 0.518 Weighted Recall: 0.516 Weighted F1 Score: 0.508 Average Specificity: 0.946
#
# Epoch: 2/200..  Training Loss: 1.449..  Test Loss: 1.176..  Test Accuracy: 0.573 Weighted Precision: 0.577 Weighted Recall: 0.573 Weighted F1 Score: 0.565 Average Specificity: 0.953
#
# Epoch: 3/200..  Training Loss: 1.332..  Test Loss: 1.036..  Test Accuracy: 0.628 Weighted Precision: 0.632 Weighted Recall: 0.628 Weighted F1 Score: 0.627 Average Specificity: 0.959
#
# Epoch: 4/200..  Training Loss: 1.248..  Test Loss: 0.959..  Test Accuracy: 0.665 Weighted Precision: 0.669 Weighted Recall: 0.665 Weighted F1 Score: 0.664 Average Specificity: 0.963
#
# Epoch: 5/200..  Training Loss: 1.193..  Test Loss: 0.996..  Test Accuracy: 0.651 Weighted Precision: 0.669 Weighted Recall: 0.651 Weighted F1 Score: 0.650 Average Specificity: 0.961
#
# Epoch: 6/200..  Training Loss: 1.136..  Test Loss: 0.893..  Test Accuracy: 0.687 Weighted Precision: 0.693 Weighted Recall: 0.687 Weighted F1 Score: 0.685 Average Specificity: 0.965
#
# Epoch: 7/200..  Training Loss: 1.101..  Test Loss: 0.819..  Test Accuracy: 0.713 Weighted Precision: 0.712 Weighted Recall: 0.713 Weighted F1 Score: 0.710 Average Specificity: 0.968
#
# Epoch: 8/200..  Training Loss: 1.075..  Test Loss: 0.808..  Test Accuracy: 0.717 Weighted Precision: 0.724 Weighted Recall: 0.717 Weighted F1 Score: 0.716 Average Specificity: 0.969
#
# Epoch: 9/200..  Training Loss: 1.035..  Test Loss: 0.778..  Test Accuracy: 0.729 Weighted Precision: 0.729 Weighted Recall: 0.729 Weighted F1 Score: 0.726 Average Specificity: 0.970
#
# Epoch: 10/200..  Training Loss: 1.021..  Test Loss: 0.769..  Test Accuracy: 0.731 Weighted Precision: 0.735 Weighted Recall: 0.731 Weighted F1 Score: 0.731 Average Specificity: 0.970
#
# Epoch: 11/200..  Training Loss: 0.990..  Test Loss: 0.751..  Test Accuracy: 0.733 Weighted Precision: 0.734 Weighted Recall: 0.733 Weighted F1 Score: 0.731 Average Specificity: 0.970
#
# Epoch: 12/200..  Training Loss: 0.978..  Test Loss: 0.707..  Test Accuracy: 0.754 Weighted Precision: 0.755 Weighted Recall: 0.754 Weighted F1 Score: 0.752 Average Specificity: 0.973
#
# Epoch: 13/200..  Training Loss: 0.954..  Test Loss: 0.711..  Test Accuracy: 0.752 Weighted Precision: 0.753 Weighted Recall: 0.752 Weighted F1 Score: 0.750 Average Specificity: 0.972
#
# Epoch: 14/200..  Training Loss: 0.937..  Test Loss: 0.684..  Test Accuracy: 0.760 Weighted Precision: 0.761 Weighted Recall: 0.760 Weighted F1 Score: 0.757 Average Specificity: 0.973
#
# Epoch: 15/200..  Training Loss: 0.918..  Test Loss: 0.671..  Test Accuracy: 0.767 Weighted Precision: 0.765 Weighted Recall: 0.767 Weighted F1 Score: 0.764 Average Specificity: 0.974
#
# Epoch: 16/200..  Training Loss: 0.901..  Test Loss: 0.657..  Test Accuracy: 0.772 Weighted Precision: 0.770 Weighted Recall: 0.772 Weighted F1 Score: 0.769 Average Specificity: 0.975
#
# Epoch: 17/200..  Training Loss: 0.883..  Test Loss: 0.671..  Test Accuracy: 0.764 Weighted Precision: 0.764 Weighted Recall: 0.764 Weighted F1 Score: 0.761 Average Specificity: 0.974
#
# Epoch: 18/200..  Training Loss: 0.881..  Test Loss: 0.624..  Test Accuracy: 0.782 Weighted Precision: 0.781 Weighted Recall: 0.782 Weighted F1 Score: 0.781 Average Specificity: 0.976
#
# Epoch: 19/200..  Training Loss: 0.864..  Test Loss: 0.637..  Test Accuracy: 0.776 Weighted Precision: 0.779 Weighted Recall: 0.776 Weighted F1 Score: 0.776 Average Specificity: 0.975
#
# Epoch: 20/200..  Training Loss: 0.853..  Test Loss: 0.618..  Test Accuracy: 0.787 Weighted Precision: 0.786 Weighted Recall: 0.787 Weighted F1 Score: 0.785 Average Specificity: 0.976
#
# Epoch: 21/200..  Training Loss: 0.839..  Test Loss: 0.612..  Test Accuracy: 0.788 Weighted Precision: 0.787 Weighted Recall: 0.788 Weighted F1 Score: 0.787 Average Specificity: 0.976
#
# Epoch: 22/200..  Training Loss: 0.828..  Test Loss: 0.605..  Test Accuracy: 0.793 Weighted Precision: 0.792 Weighted Recall: 0.793 Weighted F1 Score: 0.792 Average Specificity: 0.977
#
# Epoch: 23/200..  Training Loss: 0.820..  Test Loss: 0.605..  Test Accuracy: 0.791 Weighted Precision: 0.790 Weighted Recall: 0.791 Weighted F1 Score: 0.788 Average Specificity: 0.977
#
# Epoch: 24/200..  Training Loss: 0.813..  Test Loss: 0.597..  Test Accuracy: 0.793 Weighted Precision: 0.792 Weighted Recall: 0.793 Weighted F1 Score: 0.790 Average Specificity: 0.977
#
# Epoch: 25/200..  Training Loss: 0.804..  Test Loss: 0.590..  Test Accuracy: 0.794 Weighted Precision: 0.795 Weighted Recall: 0.794 Weighted F1 Score: 0.793 Average Specificity: 0.977
#
# Epoch: 26/200..  Training Loss: 0.794..  Test Loss: 0.564..  Test Accuracy: 0.803 Weighted Precision: 0.802 Weighted Recall: 0.803 Weighted F1 Score: 0.801 Average Specificity: 0.978
#
# Epoch: 27/200..  Training Loss: 0.787..  Test Loss: 0.564..  Test Accuracy: 0.804 Weighted Precision: 0.802 Weighted Recall: 0.804 Weighted F1 Score: 0.802 Average Specificity: 0.978
#
# Epoch: 28/200..  Training Loss: 0.785..  Test Loss: 0.587..  Test Accuracy: 0.796 Weighted Precision: 0.798 Weighted Recall: 0.796 Weighted F1 Score: 0.795 Average Specificity: 0.977
#
# Epoch: 29/200..  Training Loss: 0.772..  Test Loss: 0.558..  Test Accuracy: 0.806 Weighted Precision: 0.804 Weighted Recall: 0.806 Weighted F1 Score: 0.804 Average Specificity: 0.978
#
# Epoch: 30/200..  Training Loss: 0.764..  Test Loss: 0.580..  Test Accuracy: 0.800 Weighted Precision: 0.800 Weighted Recall: 0.800 Weighted F1 Score: 0.798 Average Specificity: 0.978
#
# Epoch: 31/200..  Training Loss: 0.762..  Test Loss: 0.559..  Test Accuracy: 0.809 Weighted Precision: 0.809 Weighted Recall: 0.809 Weighted F1 Score: 0.808 Average Specificity: 0.979
#
# Epoch: 32/200..  Training Loss: 0.751..  Test Loss: 0.569..  Test Accuracy: 0.803 Weighted Precision: 0.802 Weighted Recall: 0.803 Weighted F1 Score: 0.801 Average Specificity: 0.978
#
# Epoch: 33/200..  Training Loss: 0.746..  Test Loss: 0.542..  Test Accuracy: 0.814 Weighted Precision: 0.814 Weighted Recall: 0.814 Weighted F1 Score: 0.813 Average Specificity: 0.979
#
# Epoch: 34/200..  Training Loss: 0.745..  Test Loss: 0.541..  Test Accuracy: 0.812 Weighted Precision: 0.811 Weighted Recall: 0.812 Weighted F1 Score: 0.810 Average Specificity: 0.979
#
# Epoch: 35/200..  Training Loss: 0.739..  Test Loss: 0.549..  Test Accuracy: 0.811 Weighted Precision: 0.810 Weighted Recall: 0.811 Weighted F1 Score: 0.809 Average Specificity: 0.979
#
# Epoch: 36/200..  Training Loss: 0.724..  Test Loss: 0.550..  Test Accuracy: 0.807 Weighted Precision: 0.808 Weighted Recall: 0.807 Weighted F1 Score: 0.806 Average Specificity: 0.979
#
# Epoch: 37/200..  Training Loss: 0.723..  Test Loss: 0.528..  Test Accuracy: 0.818 Weighted Precision: 0.817 Weighted Recall: 0.818 Weighted F1 Score: 0.817 Average Specificity: 0.980
#
# Epoch: 38/200..  Training Loss: 0.724..  Test Loss: 0.534..  Test Accuracy: 0.814 Weighted Precision: 0.814 Weighted Recall: 0.814 Weighted F1 Score: 0.812 Average Specificity: 0.979
#
# Epoch: 39/200..  Training Loss: 0.712..  Test Loss: 0.528..  Test Accuracy: 0.817 Weighted Precision: 0.818 Weighted Recall: 0.817 Weighted F1 Score: 0.817 Average Specificity: 0.980
#
# Epoch: 40/200..  Training Loss: 0.711..  Test Loss: 0.515..  Test Accuracy: 0.820 Weighted Precision: 0.818 Weighted Recall: 0.820 Weighted F1 Score: 0.819 Average Specificity: 0.980
#
# Epoch: 41/200..  Training Loss: 0.700..  Test Loss: 0.517..  Test Accuracy: 0.824 Weighted Precision: 0.822 Weighted Recall: 0.824 Weighted F1 Score: 0.822 Average Specificity: 0.980
#
# Epoch: 42/200..  Training Loss: 0.701..  Test Loss: 0.542..  Test Accuracy: 0.811 Weighted Precision: 0.813 Weighted Recall: 0.811 Weighted F1 Score: 0.811 Average Specificity: 0.979
#
# Epoch: 43/200..  Training Loss: 0.696..  Test Loss: 0.515..  Test Accuracy: 0.822 Weighted Precision: 0.821 Weighted Recall: 0.822 Weighted F1 Score: 0.820 Average Specificity: 0.980
#
# Epoch: 44/200..  Training Loss: 0.688..  Test Loss: 0.518..  Test Accuracy: 0.823 Weighted Precision: 0.826 Weighted Recall: 0.823 Weighted F1 Score: 0.822 Average Specificity: 0.980
#
# Epoch: 45/200..  Training Loss: 0.693..  Test Loss: 0.517..  Test Accuracy: 0.822 Weighted Precision: 0.822 Weighted Recall: 0.822 Weighted F1 Score: 0.820 Average Specificity: 0.980
#
# Epoch: 46/200..  Training Loss: 0.682..  Test Loss: 0.505..  Test Accuracy: 0.827 Weighted Precision: 0.826 Weighted Recall: 0.827 Weighted F1 Score: 0.825 Average Specificity: 0.981
#
# Epoch: 47/200..  Training Loss: 0.685..  Test Loss: 0.502..  Test Accuracy: 0.825 Weighted Precision: 0.823 Weighted Recall: 0.825 Weighted F1 Score: 0.823 Average Specificity: 0.981
#
# Epoch: 48/200..  Training Loss: 0.674..  Test Loss: 0.504..  Test Accuracy: 0.825 Weighted Precision: 0.824 Weighted Recall: 0.825 Weighted F1 Score: 0.823 Average Specificity: 0.981
#
# Epoch: 49/200..  Training Loss: 0.671..  Test Loss: 0.506..  Test Accuracy: 0.825 Weighted Precision: 0.826 Weighted Recall: 0.825 Weighted F1 Score: 0.824 Average Specificity: 0.981
#
# Epoch: 50/200..  Training Loss: 0.672..  Test Loss: 0.507..  Test Accuracy: 0.825 Weighted Precision: 0.826 Weighted Recall: 0.825 Weighted F1 Score: 0.824 Average Specificity: 0.981
#
# Epoch: 51/200..  Training Loss: 0.663..  Test Loss: 0.499..  Test Accuracy: 0.827 Weighted Precision: 0.827 Weighted Recall: 0.827 Weighted F1 Score: 0.826 Average Specificity: 0.981
#
# Epoch: 52/200..  Training Loss: 0.660..  Test Loss: 0.503..  Test Accuracy: 0.826 Weighted Precision: 0.828 Weighted Recall: 0.826 Weighted F1 Score: 0.824 Average Specificity: 0.981
#
# Epoch: 53/200..  Training Loss: 0.659..  Test Loss: 0.508..  Test Accuracy: 0.826 Weighted Precision: 0.827 Weighted Recall: 0.826 Weighted F1 Score: 0.826 Average Specificity: 0.981
#
# Epoch: 54/200..  Training Loss: 0.654..  Test Loss: 0.504..  Test Accuracy: 0.824 Weighted Precision: 0.826 Weighted Recall: 0.824 Weighted F1 Score: 0.824 Average Specificity: 0.980
#
# Epoch: 55/200..  Training Loss: 0.651..  Test Loss: 0.495..  Test Accuracy: 0.828 Weighted Precision: 0.828 Weighted Recall: 0.828 Weighted F1 Score: 0.826 Average Specificity: 0.981
#
# Epoch: 56/200..  Training Loss: 0.653..  Test Loss: 0.494..  Test Accuracy: 0.829 Weighted Precision: 0.829 Weighted Recall: 0.829 Weighted F1 Score: 0.828 Average Specificity: 0.981
#
# Epoch: 57/200..  Training Loss: 0.641..  Test Loss: 0.483..  Test Accuracy: 0.832 Weighted Precision: 0.831 Weighted Recall: 0.832 Weighted F1 Score: 0.830 Average Specificity: 0.981
#
# Epoch: 58/200..  Training Loss: 0.642..  Test Loss: 0.491..  Test Accuracy: 0.834 Weighted Precision: 0.834 Weighted Recall: 0.834 Weighted F1 Score: 0.832 Average Specificity: 0.982
#
# Epoch: 59/200..  Training Loss: 0.639..  Test Loss: 0.494..  Test Accuracy: 0.829 Weighted Precision: 0.829 Weighted Recall: 0.829 Weighted F1 Score: 0.828 Average Specificity: 0.981
#
# Epoch: 60/200..  Training Loss: 0.639..  Test Loss: 0.480..  Test Accuracy: 0.834 Weighted Precision: 0.832 Weighted Recall: 0.834 Weighted F1 Score: 0.832 Average Specificity: 0.982
#
# Epoch: 61/200..  Training Loss: 0.635..  Test Loss: 0.492..  Test Accuracy: 0.832 Weighted Precision: 0.831 Weighted Recall: 0.832 Weighted F1 Score: 0.830 Average Specificity: 0.981
#
# Epoch: 62/200..  Training Loss: 0.633..  Test Loss: 0.477..  Test Accuracy: 0.834 Weighted Precision: 0.833 Weighted Recall: 0.834 Weighted F1 Score: 0.833 Average Specificity: 0.982
#
# Epoch: 63/200..  Training Loss: 0.632..  Test Loss: 0.478..  Test Accuracy: 0.836 Weighted Precision: 0.836 Weighted Recall: 0.836 Weighted F1 Score: 0.836 Average Specificity: 0.982
#
# Epoch: 64/200..  Training Loss: 0.619..  Test Loss: 0.480..  Test Accuracy: 0.836 Weighted Precision: 0.836 Weighted Recall: 0.836 Weighted F1 Score: 0.836 Average Specificity: 0.982
#
# Epoch: 65/200..  Training Loss: 0.616..  Test Loss: 0.488..  Test Accuracy: 0.831 Weighted Precision: 0.830 Weighted Recall: 0.831 Weighted F1 Score: 0.829 Average Specificity: 0.981
#
# Epoch: 66/200..  Training Loss: 0.621..  Test Loss: 0.481..  Test Accuracy: 0.834 Weighted Precision: 0.834 Weighted Recall: 0.834 Weighted F1 Score: 0.833 Average Specificity: 0.982
#
# Epoch: 67/200..  Training Loss: 0.615..  Test Loss: 0.487..  Test Accuracy: 0.833 Weighted Precision: 0.833 Weighted Recall: 0.833 Weighted F1 Score: 0.832 Average Specificity: 0.981
#
# Epoch: 68/200..  Training Loss: 0.618..  Test Loss: 0.473..  Test Accuracy: 0.837 Weighted Precision: 0.836 Weighted Recall: 0.837 Weighted F1 Score: 0.836 Average Specificity: 0.982
#
# Epoch: 69/200..  Training Loss: 0.611..  Test Loss: 0.475..  Test Accuracy: 0.839 Weighted Precision: 0.840 Weighted Recall: 0.839 Weighted F1 Score: 0.838 Average Specificity: 0.982
#
# Epoch: 70/200..  Training Loss: 0.603..  Test Loss: 0.484..  Test Accuracy: 0.834 Weighted Precision: 0.835 Weighted Recall: 0.834 Weighted F1 Score: 0.833 Average Specificity: 0.982
#
# Epoch: 71/200..  Training Loss: 0.600..  Test Loss: 0.479..  Test Accuracy: 0.838 Weighted Precision: 0.838 Weighted Recall: 0.838 Weighted F1 Score: 0.838 Average Specificity: 0.982
#
# Epoch: 72/200..  Training Loss: 0.602..  Test Loss: 0.468..  Test Accuracy: 0.839 Weighted Precision: 0.839 Weighted Recall: 0.839 Weighted F1 Score: 0.839 Average Specificity: 0.982
#
# Epoch: 73/200..  Training Loss: 0.598..  Test Loss: 0.475..  Test Accuracy: 0.834 Weighted Precision: 0.834 Weighted Recall: 0.834 Weighted F1 Score: 0.832 Average Specificity: 0.982
#
# Epoch: 74/200..  Training Loss: 0.597..  Test Loss: 0.480..  Test Accuracy: 0.833 Weighted Precision: 0.833 Weighted Recall: 0.833 Weighted F1 Score: 0.832 Average Specificity: 0.981
#
# Epoch: 75/200..  Training Loss: 0.596..  Test Loss: 0.462..  Test Accuracy: 0.842 Weighted Precision: 0.841 Weighted Recall: 0.842 Weighted F1 Score: 0.841 Average Specificity: 0.982
#
# Epoch: 76/200..  Training Loss: 0.595..  Test Loss: 0.466..  Test Accuracy: 0.840 Weighted Precision: 0.840 Weighted Recall: 0.840 Weighted F1 Score: 0.839 Average Specificity: 0.982
#
# Epoch: 77/200..  Training Loss: 0.589..  Test Loss: 0.453..  Test Accuracy: 0.844 Weighted Precision: 0.844 Weighted Recall: 0.844 Weighted F1 Score: 0.844 Average Specificity: 0.983
#
# Epoch: 78/200..  Training Loss: 0.585..  Test Loss: 0.466..  Test Accuracy: 0.842 Weighted Precision: 0.842 Weighted Recall: 0.842 Weighted F1 Score: 0.841 Average Specificity: 0.982
#
# Epoch: 79/200..  Training Loss: 0.585..  Test Loss: 0.458..  Test Accuracy: 0.841 Weighted Precision: 0.841 Weighted Recall: 0.841 Weighted F1 Score: 0.841 Average Specificity: 0.982
#
# Epoch: 80/200..  Training Loss: 0.588..  Test Loss: 0.460..  Test Accuracy: 0.844 Weighted Precision: 0.844 Weighted Recall: 0.844 Weighted F1 Score: 0.843 Average Specificity: 0.983
#
# Epoch: 81/200..  Training Loss: 0.580..  Test Loss: 0.463..  Test Accuracy: 0.840 Weighted Precision: 0.840 Weighted Recall: 0.840 Weighted F1 Score: 0.840 Average Specificity: 0.982
#
# Epoch: 82/200..  Training Loss: 0.582..  Test Loss: 0.459..  Test Accuracy: 0.843 Weighted Precision: 0.843 Weighted Recall: 0.843 Weighted F1 Score: 0.842 Average Specificity: 0.983
#
# Epoch: 83/200..  Training Loss: 0.573..  Test Loss: 0.466..  Test Accuracy: 0.841 Weighted Precision: 0.841 Weighted Recall: 0.841 Weighted F1 Score: 0.840 Average Specificity: 0.982
#
# Epoch: 84/200..  Training Loss: 0.581..  Test Loss: 0.454..  Test Accuracy: 0.845 Weighted Precision: 0.845 Weighted Recall: 0.845 Weighted F1 Score: 0.844 Average Specificity: 0.983
#
# Epoch: 85/200..  Training Loss: 0.572..  Test Loss: 0.455..  Test Accuracy: 0.845 Weighted Precision: 0.845 Weighted Recall: 0.845 Weighted F1 Score: 0.845 Average Specificity: 0.983
#
# Epoch: 86/200..  Training Loss: 0.565..  Test Loss: 0.464..  Test Accuracy: 0.841 Weighted Precision: 0.840 Weighted Recall: 0.841 Weighted F1 Score: 0.839 Average Specificity: 0.982
#
# Epoch: 87/200..  Training Loss: 0.568..  Test Loss: 0.454..  Test Accuracy: 0.845 Weighted Precision: 0.845 Weighted Recall: 0.845 Weighted F1 Score: 0.844 Average Specificity: 0.983
#
# Epoch: 88/200..  Training Loss: 0.563..  Test Loss: 0.447..  Test Accuracy: 0.847 Weighted Precision: 0.847 Weighted Recall: 0.847 Weighted F1 Score: 0.846 Average Specificity: 0.983
#
# Epoch: 89/200..  Training Loss: 0.559..  Test Loss: 0.455..  Test Accuracy: 0.842 Weighted Precision: 0.843 Weighted Recall: 0.842 Weighted F1 Score: 0.842 Average Specificity: 0.982
#
# Epoch: 90/200..  Training Loss: 0.563..  Test Loss: 0.449..  Test Accuracy: 0.848 Weighted Precision: 0.847 Weighted Recall: 0.848 Weighted F1 Score: 0.847 Average Specificity: 0.983
#
# Epoch: 91/200..  Training Loss: 0.558..  Test Loss: 0.448..  Test Accuracy: 0.848 Weighted Precision: 0.847 Weighted Recall: 0.848 Weighted F1 Score: 0.847 Average Specificity: 0.983
#
# Epoch: 92/200..  Training Loss: 0.551..  Test Loss: 0.446..  Test Accuracy: 0.847 Weighted Precision: 0.846 Weighted Recall: 0.847 Weighted F1 Score: 0.846 Average Specificity: 0.983
#
# Epoch: 93/200..  Training Loss: 0.552..  Test Loss: 0.454..  Test Accuracy: 0.845 Weighted Precision: 0.844 Weighted Recall: 0.845 Weighted F1 Score: 0.844 Average Specificity: 0.983
#
# Epoch: 94/200..  Training Loss: 0.553..  Test Loss: 0.462..  Test Accuracy: 0.841 Weighted Precision: 0.842 Weighted Recall: 0.841 Weighted F1 Score: 0.841 Average Specificity: 0.982
#
# Epoch: 95/200..  Training Loss: 0.549..  Test Loss: 0.450..  Test Accuracy: 0.847 Weighted Precision: 0.846 Weighted Recall: 0.847 Weighted F1 Score: 0.845 Average Specificity: 0.983
#
# Epoch: 96/200..  Training Loss: 0.545..  Test Loss: 0.439..  Test Accuracy: 0.851 Weighted Precision: 0.850 Weighted Recall: 0.851 Weighted F1 Score: 0.850 Average Specificity: 0.983
#
# Epoch: 97/200..  Training Loss: 0.544..  Test Loss: 0.452..  Test Accuracy: 0.848 Weighted Precision: 0.848 Weighted Recall: 0.848 Weighted F1 Score: 0.847 Average Specificity: 0.983
#
# Epoch: 98/200..  Training Loss: 0.552..  Test Loss: 0.464..  Test Accuracy: 0.842 Weighted Precision: 0.841 Weighted Recall: 0.842 Weighted F1 Score: 0.840 Average Specificity: 0.982
#
# Epoch: 99/200..  Training Loss: 0.553..  Test Loss: 0.446..  Test Accuracy: 0.850 Weighted Precision: 0.850 Weighted Recall: 0.850 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 100/200..  Training Loss: 0.542..  Test Loss: 0.439..  Test Accuracy: 0.850 Weighted Precision: 0.849 Weighted Recall: 0.850 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 101/200..  Training Loss: 0.536..  Test Loss: 0.447..  Test Accuracy: 0.851 Weighted Precision: 0.851 Weighted Recall: 0.851 Weighted F1 Score: 0.851 Average Specificity: 0.983
#
# Epoch: 102/200..  Training Loss: 0.537..  Test Loss: 0.445..  Test Accuracy: 0.849 Weighted Precision: 0.849 Weighted Recall: 0.849 Weighted F1 Score: 0.848 Average Specificity: 0.983
#
# Epoch: 103/200..  Training Loss: 0.534..  Test Loss: 0.450..  Test Accuracy: 0.849 Weighted Precision: 0.849 Weighted Recall: 0.849 Weighted F1 Score: 0.848 Average Specificity: 0.983
#
# Epoch: 104/200..  Training Loss: 0.534..  Test Loss: 0.444..  Test Accuracy: 0.851 Weighted Precision: 0.851 Weighted Recall: 0.851 Weighted F1 Score: 0.850 Average Specificity: 0.983
#
# Epoch: 105/200..  Training Loss: 0.539..  Test Loss: 0.458..  Test Accuracy: 0.845 Weighted Precision: 0.846 Weighted Recall: 0.845 Weighted F1 Score: 0.844 Average Specificity: 0.983
#
# Epoch: 106/200..  Training Loss: 0.528..  Test Loss: 0.443..  Test Accuracy: 0.851 Weighted Precision: 0.851 Weighted Recall: 0.851 Weighted F1 Score: 0.850 Average Specificity: 0.983
#
# Epoch: 107/200..  Training Loss: 0.531..  Test Loss: 0.445..  Test Accuracy: 0.847 Weighted Precision: 0.846 Weighted Recall: 0.847 Weighted F1 Score: 0.846 Average Specificity: 0.983
#
# Epoch: 108/200..  Training Loss: 0.523..  Test Loss: 0.463..  Test Accuracy: 0.844 Weighted Precision: 0.843 Weighted Recall: 0.844 Weighted F1 Score: 0.843 Average Specificity: 0.983
#
# Epoch: 109/200..  Training Loss: 0.527..  Test Loss: 0.445..  Test Accuracy: 0.849 Weighted Precision: 0.850 Weighted Recall: 0.849 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 110/200..  Training Loss: 0.523..  Test Loss: 0.438..  Test Accuracy: 0.854 Weighted Precision: 0.853 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 111/200..  Training Loss: 0.520..  Test Loss: 0.447..  Test Accuracy: 0.849 Weighted Precision: 0.849 Weighted Recall: 0.849 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 112/200..  Training Loss: 0.520..  Test Loss: 0.441..  Test Accuracy: 0.848 Weighted Precision: 0.849 Weighted Recall: 0.848 Weighted F1 Score: 0.848 Average Specificity: 0.983
#
# Epoch: 113/200..  Training Loss: 0.521..  Test Loss: 0.444..  Test Accuracy: 0.848 Weighted Precision: 0.847 Weighted Recall: 0.848 Weighted F1 Score: 0.847 Average Specificity: 0.983
#
# Epoch: 114/200..  Training Loss: 0.517..  Test Loss: 0.435..  Test Accuracy: 0.852 Weighted Precision: 0.851 Weighted Recall: 0.852 Weighted F1 Score: 0.851 Average Specificity: 0.983
#
# Epoch: 115/200..  Training Loss: 0.516..  Test Loss: 0.440..  Test Accuracy: 0.849 Weighted Precision: 0.849 Weighted Recall: 0.849 Weighted F1 Score: 0.848 Average Specificity: 0.983
#
# Epoch: 116/200..  Training Loss: 0.509..  Test Loss: 0.434..  Test Accuracy: 0.854 Weighted Precision: 0.853 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 117/200..  Training Loss: 0.504..  Test Loss: 0.440..  Test Accuracy: 0.849 Weighted Precision: 0.850 Weighted Recall: 0.849 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 118/200..  Training Loss: 0.518..  Test Loss: 0.437..  Test Accuracy: 0.853 Weighted Precision: 0.852 Weighted Recall: 0.853 Weighted F1 Score: 0.852 Average Specificity: 0.984
#
# Epoch: 119/200..  Training Loss: 0.506..  Test Loss: 0.450..  Test Accuracy: 0.848 Weighted Precision: 0.847 Weighted Recall: 0.848 Weighted F1 Score: 0.847 Average Specificity: 0.983
#
# Epoch: 120/200..  Training Loss: 0.502..  Test Loss: 0.440..  Test Accuracy: 0.849 Weighted Precision: 0.848 Weighted Recall: 0.849 Weighted F1 Score: 0.848 Average Specificity: 0.983
#
# Epoch: 121/200..  Training Loss: 0.510..  Test Loss: 0.441..  Test Accuracy: 0.850 Weighted Precision: 0.849 Weighted Recall: 0.850 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 122/200..  Training Loss: 0.504..  Test Loss: 0.449..  Test Accuracy: 0.847 Weighted Precision: 0.846 Weighted Recall: 0.847 Weighted F1 Score: 0.845 Average Specificity: 0.983
#
# Epoch: 123/200..  Training Loss: 0.500..  Test Loss: 0.436..  Test Accuracy: 0.851 Weighted Precision: 0.850 Weighted Recall: 0.851 Weighted F1 Score: 0.850 Average Specificity: 0.983
#
# Epoch: 124/200..  Training Loss: 0.503..  Test Loss: 0.435..  Test Accuracy: 0.853 Weighted Precision: 0.852 Weighted Recall: 0.853 Weighted F1 Score: 0.852 Average Specificity: 0.984
#
# Epoch: 125/200..  Training Loss: 0.496..  Test Loss: 0.446..  Test Accuracy: 0.851 Weighted Precision: 0.852 Weighted Recall: 0.851 Weighted F1 Score: 0.851 Average Specificity: 0.983
#
# Epoch: 126/200..  Training Loss: 0.505..  Test Loss: 0.433..  Test Accuracy: 0.854 Weighted Precision: 0.854 Weighted Recall: 0.854 Weighted F1 Score: 0.854 Average Specificity: 0.984
#
# Epoch: 127/200..  Training Loss: 0.491..  Test Loss: 0.437..  Test Accuracy: 0.854 Weighted Precision: 0.854 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 128/200..  Training Loss: 0.499..  Test Loss: 0.437..  Test Accuracy: 0.852 Weighted Precision: 0.852 Weighted Recall: 0.852 Weighted F1 Score: 0.851 Average Specificity: 0.984
#
# Epoch: 129/200..  Training Loss: 0.490..  Test Loss: 0.437..  Test Accuracy: 0.856 Weighted Precision: 0.855 Weighted Recall: 0.856 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 130/200..  Training Loss: 0.502..  Test Loss: 0.438..  Test Accuracy: 0.850 Weighted Precision: 0.851 Weighted Recall: 0.850 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 131/200..  Training Loss: 0.493..  Test Loss: 0.437..  Test Accuracy: 0.850 Weighted Precision: 0.850 Weighted Recall: 0.850 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 132/200..  Training Loss: 0.488..  Test Loss: 0.431..  Test Accuracy: 0.857 Weighted Precision: 0.856 Weighted Recall: 0.857 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 133/200..  Training Loss: 0.482..  Test Loss: 0.438..  Test Accuracy: 0.851 Weighted Precision: 0.851 Weighted Recall: 0.851 Weighted F1 Score: 0.851 Average Specificity: 0.983
#
# Epoch: 134/200..  Training Loss: 0.488..  Test Loss: 0.431..  Test Accuracy: 0.854 Weighted Precision: 0.854 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 135/200..  Training Loss: 0.490..  Test Loss: 0.428..  Test Accuracy: 0.855 Weighted Precision: 0.855 Weighted Recall: 0.855 Weighted F1 Score: 0.854 Average Specificity: 0.984
#
# Epoch: 136/200..  Training Loss: 0.489..  Test Loss: 0.433..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 137/200..  Training Loss: 0.483..  Test Loss: 0.425..  Test Accuracy: 0.855 Weighted Precision: 0.855 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 138/200..  Training Loss: 0.480..  Test Loss: 0.438..  Test Accuracy: 0.855 Weighted Precision: 0.856 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 139/200..  Training Loss: 0.485..  Test Loss: 0.428..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 140/200..  Training Loss: 0.479..  Test Loss: 0.436..  Test Accuracy: 0.853 Weighted Precision: 0.853 Weighted Recall: 0.853 Weighted F1 Score: 0.852 Average Specificity: 0.984
#
# Epoch: 141/200..  Training Loss: 0.478..  Test Loss: 0.429..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 142/200..  Training Loss: 0.485..  Test Loss: 0.430..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 143/200..  Training Loss: 0.469..  Test Loss: 0.424..  Test Accuracy: 0.860 Weighted Precision: 0.859 Weighted Recall: 0.860 Weighted F1 Score: 0.859 Average Specificity: 0.984
#
# Epoch: 144/200..  Training Loss: 0.480..  Test Loss: 0.432..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 145/200..  Training Loss: 0.475..  Test Loss: 0.433..  Test Accuracy: 0.856 Weighted Precision: 0.857 Weighted Recall: 0.856 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 146/200..  Training Loss: 0.473..  Test Loss: 0.429..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 147/200..  Training Loss: 0.473..  Test Loss: 0.428..  Test Accuracy: 0.859 Weighted Precision: 0.859 Weighted Recall: 0.859 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 148/200..  Training Loss: 0.470..  Test Loss: 0.429..  Test Accuracy: 0.858 Weighted Precision: 0.856 Weighted Recall: 0.858 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 149/200..  Training Loss: 0.476..  Test Loss: 0.437..  Test Accuracy: 0.853 Weighted Precision: 0.853 Weighted Recall: 0.853 Weighted F1 Score: 0.852 Average Specificity: 0.984
#
# Epoch: 150/200..  Training Loss: 0.465..  Test Loss: 0.431..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 151/200..  Training Loss: 0.465..  Test Loss: 0.433..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 152/200..  Training Loss: 0.465..  Test Loss: 0.447..  Test Accuracy: 0.849 Weighted Precision: 0.849 Weighted Recall: 0.849 Weighted F1 Score: 0.849 Average Specificity: 0.983
#
# Epoch: 153/200..  Training Loss: 0.469..  Test Loss: 0.429..  Test Accuracy: 0.855 Weighted Precision: 0.855 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 154/200..  Training Loss: 0.462..  Test Loss: 0.429..  Test Accuracy: 0.855 Weighted Precision: 0.854 Weighted Recall: 0.855 Weighted F1 Score: 0.854 Average Specificity: 0.984
#
# Epoch: 155/200..  Training Loss: 0.467..  Test Loss: 0.425..  Test Accuracy: 0.858 Weighted Precision: 0.859 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 156/200..  Training Loss: 0.458..  Test Loss: 0.439..  Test Accuracy: 0.854 Weighted Precision: 0.854 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 157/200..  Training Loss: 0.455..  Test Loss: 0.425..  Test Accuracy: 0.857 Weighted Precision: 0.858 Weighted Recall: 0.857 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 158/200..  Training Loss: 0.464..  Test Loss: 0.435..  Test Accuracy: 0.853 Weighted Precision: 0.854 Weighted Recall: 0.853 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 159/200..  Training Loss: 0.455..  Test Loss: 0.433..  Test Accuracy: 0.854 Weighted Precision: 0.853 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 160/200..  Training Loss: 0.460..  Test Loss: 0.427..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 161/200..  Training Loss: 0.458..  Test Loss: 0.423..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 162/200..  Training Loss: 0.457..  Test Loss: 0.442..  Test Accuracy: 0.855 Weighted Precision: 0.855 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 163/200..  Training Loss: 0.450..  Test Loss: 0.425..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 164/200..  Training Loss: 0.461..  Test Loss: 0.422..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 165/200..  Training Loss: 0.451..  Test Loss: 0.427..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 166/200..  Training Loss: 0.448..  Test Loss: 0.430..  Test Accuracy: 0.858 Weighted Precision: 0.856 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 167/200..  Training Loss: 0.448..  Test Loss: 0.428..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 168/200..  Training Loss: 0.451..  Test Loss: 0.424..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 169/200..  Training Loss: 0.450..  Test Loss: 0.424..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 170/200..  Training Loss: 0.448..  Test Loss: 0.426..  Test Accuracy: 0.860 Weighted Precision: 0.860 Weighted Recall: 0.860 Weighted F1 Score: 0.860 Average Specificity: 0.984
#
# Epoch: 171/200..  Training Loss: 0.440..  Test Loss: 0.427..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 172/200..  Training Loss: 0.450..  Test Loss: 0.422..  Test Accuracy: 0.859 Weighted Precision: 0.859 Weighted Recall: 0.859 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 173/200..  Training Loss: 0.445..  Test Loss: 0.425..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 174/200..  Training Loss: 0.441..  Test Loss: 0.427..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 175/200..  Training Loss: 0.440..  Test Loss: 0.426..  Test Accuracy: 0.860 Weighted Precision: 0.859 Weighted Recall: 0.860 Weighted F1 Score: 0.859 Average Specificity: 0.984
#
# Epoch: 176/200..  Training Loss: 0.443..  Test Loss: 0.433..  Test Accuracy: 0.855 Weighted Precision: 0.856 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 177/200..  Training Loss: 0.436..  Test Loss: 0.438..  Test Accuracy: 0.854 Weighted Precision: 0.854 Weighted Recall: 0.854 Weighted F1 Score: 0.853 Average Specificity: 0.984
#
# Epoch: 178/200..  Training Loss: 0.441..  Test Loss: 0.428..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 179/200..  Training Loss: 0.441..  Test Loss: 0.427..  Test Accuracy: 0.856 Weighted Precision: 0.855 Weighted Recall: 0.856 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 180/200..  Training Loss: 0.432..  Test Loss: 0.427..  Test Accuracy: 0.859 Weighted Precision: 0.860 Weighted Recall: 0.859 Weighted F1 Score: 0.859 Average Specificity: 0.984
#
# Epoch: 181/200..  Training Loss: 0.439..  Test Loss: 0.429..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 182/200..  Training Loss: 0.441..  Test Loss: 0.426..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 183/200..  Training Loss: 0.439..  Test Loss: 0.428..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 184/200..  Training Loss: 0.433..  Test Loss: 0.435..  Test Accuracy: 0.855 Weighted Precision: 0.856 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 185/200..  Training Loss: 0.433..  Test Loss: 0.437..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 186/200..  Training Loss: 0.437..  Test Loss: 0.430..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 187/200..  Training Loss: 0.431..  Test Loss: 0.424..  Test Accuracy: 0.860 Weighted Precision: 0.861 Weighted Recall: 0.860 Weighted F1 Score: 0.860 Average Specificity: 0.984
#
# Epoch: 188/200..  Training Loss: 0.434..  Test Loss: 0.426..  Test Accuracy: 0.860 Weighted Precision: 0.860 Weighted Recall: 0.860 Weighted F1 Score: 0.860 Average Specificity: 0.984
#
# Epoch: 189/200..  Training Loss: 0.432..  Test Loss: 0.431..  Test Accuracy: 0.857 Weighted Precision: 0.858 Weighted Recall: 0.857 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 190/200..  Training Loss: 0.433..  Test Loss: 0.431..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 191/200..  Training Loss: 0.432..  Test Loss: 0.419..  Test Accuracy: 0.859 Weighted Precision: 0.859 Weighted Recall: 0.859 Weighted F1 Score: 0.859 Average Specificity: 0.984
#
# Epoch: 192/200..  Training Loss: 0.426..  Test Loss: 0.428..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 193/200..  Training Loss: 0.428..  Test Loss: 0.425..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 194/200..  Training Loss: 0.429..  Test Loss: 0.426..  Test Accuracy: 0.856 Weighted Precision: 0.856 Weighted Recall: 0.856 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Epoch: 195/200..  Training Loss: 0.425..  Test Loss: 0.429..  Test Accuracy: 0.858 Weighted Precision: 0.858 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 196/200..  Training Loss: 0.421..  Test Loss: 0.437..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 197/200..  Training Loss: 0.427..  Test Loss: 0.425..  Test Accuracy: 0.858 Weighted Precision: 0.857 Weighted Recall: 0.858 Weighted F1 Score: 0.857 Average Specificity: 0.984
#
# Epoch: 198/200..  Training Loss: 0.426..  Test Loss: 0.433..  Test Accuracy: 0.855 Weighted Precision: 0.855 Weighted Recall: 0.855 Weighted F1 Score: 0.855 Average Specificity: 0.984
#
# Epoch: 199/200..  Training Loss: 0.424..  Test Loss: 0.429..  Test Accuracy: 0.858 Weighted Precision: 0.859 Weighted Recall: 0.858 Weighted F1 Score: 0.858 Average Specificity: 0.984
#
# Epoch: 200/200..  Training Loss: 0.421..  Test Loss: 0.433..  Test Accuracy: 0.857 Weighted Precision: 0.857 Weighted Recall: 0.857 Weighted F1 Score: 0.856 Average Specificity: 0.984
#
# Matriz de Confusión

# %%
plot_confusion_matrix(cm, clases, title="Matriz de Confusión")

# %%
#Graficar pérdidas de entrenamiento y validación
plt.plot(train_losses, label='Pérdidas de Entrenamiento')
plt.plot(test_losses, label='Pérdidas de Validación')
plt.legend(frameon=False)

# %%
#Graficar los indicadores de validación
plt.plot(precisions, label='Precisión')
plt.plot(recalls, label='Recall')  
plt.plot(f1_scores, label='F1')  
plt.plot(accus, label='Exactitud')  
plt.plot(avg_specificities, label='Especificidad')  
plt.legend(frameon=True)

# %%
#Calcular y graficar ROC y AUC
all_labels = []
all_probs = []

model.eval()
with torch.no_grad():
  for images, labels in testloader:
    log_ps = model(images)
    ps = torch.softmax(log_ps, dim=1)
    
    all_labels.extend(labels.cpu().numpy())
    all_probs.extend(ps.cpu().numpy())

all_labels = np.array(all_labels)
all_probs = np.array(all_probs)

# Calcular ROC para cada clase
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(cantidadClases):
  fpr[i], tpr[i], _ = roc_curve(all_labels == i, all_probs[:, i])
  roc_auc[i] = auc(fpr[i], tpr[i])

# Graficar ROC para cada clase
plt.figure()
for i in range(cantidadClases):
  plt.plot(fpr[i], tpr[i], label='{} (area = {:.2f})'.format(clases[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva Característica Operativa del Receptor (ROC)')
plt.legend(loc="lower right")
plt.show()

# Calcular AUC
overall_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
print("Area Bajo la Curva (AUC): {:.2f}".format(overall_auc))
# Out:
# Area Bajo la Curva (AUC): 0.99

# %%
torch.save(model.state_dict(), 'modelo-entrenado.pth') # Guardar el modelo
